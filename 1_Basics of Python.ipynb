# %% [markdown]
# We recommended you to read **Python Onboarding** up to the end.
#
# This Notebook is an abstract version of Python basics for those, who would like to freshen up their Pyhton skills or use it as a quick reference to some ferquently-used syntaxes.

# %% [markdown]
# ### 📖Your First Code in Python
#
# You are going to print a text with a single line of code.`Print` is a very useful syntax.
#
# ➡️Python is **C**ase sensitive, so print is different from **P**rint.

# %%
print ("I am excited to learn Python within this course.")
print ("hooray!!!")

# %% [markdown]
# ### 📖Variables

# %%
# define a variable called x with a value of 2
x = 2

# print x variable
print (x)

# %% [markdown]
# You can move values across different variables

# %%
# our new variable var_a holds a number

var_a = 1
print ("var_a is", var_a)

b = var_a
print ("b is",b)

#what is stored in b?

# %% [markdown]
# ### 📖Data Types

# %%
# m is an interger variable
m = 2
print (m , "is integer")

# n is a float variable
n = 2.3
print (n , "is float")

# t is a string variable
t = "Pythooon"
print (t , "is string")

# b is a boolean variable
b = 2 > 3
print (b , "is boolean")

# a_list is a list
a_list = [1, 2, 3, 'a', 'b', 'c']
print (a_list, "is a list")

# b_tuple is a list
b_tuple = (1, 2, 3, 'a', 'b', 'c')
print (b_tuple, "is a tuple")

# %%
print ("The first item in a_list is", a_list[0])

# %% [markdown]
# ➡️Do not use ``keywords`` of Python

# %%
import keyword
keyword.kwlist

# %% [markdown]
# ### ✏️Task:
# Write a code to calculate area of a rectangle!!
# 1. define two variables for the two sides of rectangle
# 2. multiple them by "*"
# 3. print the result

# %%
# Your solution here:

# %%
# Sample solution

length = 3
width = 7

area = length * width

print("The area of the rectangle is", area,'.' )

# %% [markdown]
# ### 📖Strings

# %% [markdown]
# explore what you can do with strings

# %%
#Strings:
a="Hello"
print (a)

b="abcd765"
print (b)

c="Hello" + " " + "Jamal"
print (c)

d="Hello" * 3 
print (d)

e=len(a)
print (e)

f="5"+"3"
print (f)

# %%
a= "street_cph_buffer.shp"
print ("file extension is", a[-4:])
print ("file name is", a[0:-4])

# %% [markdown]
# ### 📖Operators

# %% [markdown]
# Comparison operators

# %%
5 < 7 # < less than

# %%
5 > 6 #> greater than

# %%
6 == 6  #== equal

# %%
3 != 4 #!= not equal

# %%
1 >= 0.5 #>= greater than or equal

# %%
1 <= 0.6 #<= less than or equal

# %% [markdown]
# ### 📖Writing a Python ``function``

# %%
def my_function(): 
    print ("My function is great")

# %%
my_function()

# %%
def sum_two_numbers(a, b): 
    return a + b

# %%
sum_two_numbers(4, 5)

# %% [markdown]
# ### ✏️Task:
# write a function to calculate the area of a triangle.

# %%
# Your solution here:

# %%
# Sample solution

def triangle_area(base, height):
    return 0.5 * base * height

base = 3
height = 2
area = triangle_area(base, height)
print(f"The area of the triangle is", area,".")

# %% [markdown]
# ### 📖Python Methods
#
# A Python method is a function/property/behaviour that you can call on an object; it is a piece of code to execute on that object. You can add a '.' after your object and hold TAB button to see the existing methods.

# %%
mytext  = "this is my text"
newtext = mytext.upper()
captext = mytext.capitalize()
print (newtext)
print (captext)

# %% [markdown]
# ### 📖Control Flows
#
# Control flow is the order in which individual statements, instructions, or function calls are executed or evaluated. The control flow of a Python program is regulated by conditional statements, loops, and function calls.
#
# Here are a few examples of **conditional statements**:

# %%
x = 2 #change this value and see the results
if x >= 0:
    print ('x is positive')
else:
    print ('x is negative')

# %%
x= -5
if x>0 and x<10:
    print ("x is between 1..9")
elif x<20:
    print ("x is between 10..19")
elif x<=0:
    print ("x is less or equal than 0")
else:
    print ("x is greater or equal than 20")

# %%
x = 1
if x in [1,2,3]:
    print ('x is in list')
    if x == 1:
        print ('x is 1')

# %% [markdown]
# Here are a few examples of **loops**:

# %%
primes = [2,3,5,7] 
for prime in primes: 
    print (prime)

# %%
for i in range(1,10):
    print (i)

# %%
count = 0 
while count < 5: 
    print (count) 
    count = count + 1

# %%
x = 0
while 1:
    print (x) #stops loop
    if x == 5:
        break
    x += 1

# %%
x = 0
if x == 0:
    pass       #do nothing
else:
    print ("x is not zero")

# %%
x = 0
while 1:
    print ("x is", x)
    if x == 5:
        break #stops loop
    x += 1 #same as x = x+1
#code after loop

# %%
x = 0
if x == 0:
    pass #do nothing
    print ('x is  zero')

else:
    print ('x is not zero')

# %%
for x in range(0,100):
    if x % 2 == 0: # % = modulos
        print (x, ' is even')
        continue #restart loop
    print (x, ' is odd')

# %%
# let's create a list of odd and even numbers <100
odd_list=[]
even_list=[]

for x in range(0,100):
    if x % 2 == 0: # % = modulos
        even_list.append(x)
        continue #restart loop
    odd_list.append(x)
print ("list of odd numbers", odd_list)
print ("================================================")
print ("list of even numbers", even_list)

# %% [markdown]
# A more complex example of guessing a random number using **control flows**:

# %%
import random

no_attempts = 0
target_num = random.randrange(0, 100)

while True:
    no_attempts += 1
    num_input = input("Enter a valid number between 0 and 100: ")
    
    try:
        num = int(num_input)
    except ValueError:
        print("Please enter a valid integer.")
        continue
    
    if num < target_num:
        print("Your guess is smaller than the target number.")
    elif num > target_num:
        print("Your guess is greater than the target number.")
    else:
        print("Right answer :-)")
        print("Attempts needed: " + str(no_attempts))
        break

# %% [markdown]
# ### 📖Import and use Python modules

# %%
#Import square root function from module math

import math
math.sqrt(4)

import math as m
m.sqrt(4)

from math import sqrt
sqrt(4)

# %% [markdown]
# ### 📖Slicing of Strings, Lists, Tuples

# %%
# slicing of a string
txt = "Hello World"

txt[0]

# %%
txt[0:5]

# %%
txt[-1]

# %%
# slicing of a list
aList = [1, 2, 4, "txt"]

aList[0]

# %%
aList[1:3]

# %%
aList[-2:-1]

# %%
# use length of a list in a loop
for i in range(0,len(aList)):
    print (aList[i])

# %% [markdown]
# ### 📖Tuples
#
# Tuples are used to store multiple items in a single variable.
# A tuple is a collection which is ordered and unchangeable. Tuples are written with round brackets.

# %%
num =10
name = "Far"
height = 1.613

print ("Far's height is %.2f" % (height))

print ("After %i measurement the height of %s is %.3f" % (num, name, height))

# %% [markdown]
# ### 📖Dictionaries
#
# Dictionaries are used to store data values in key:value pairs. A dictionary is a collection which is ordered, changeable and do not allow duplicates.

# %%
population = {"Denmark": 5760694, 
              "Austria": 8460390, 
              "Norway": 5342696}

popDK = population["Denmark"]
print ("Population of Denmark: %i" % (popDK))

# %%
staffID = {9917023: "Jamal Jokar", 
           10012673: "Carsten Kessler", 
           3000031: "Farzaneh Sadeghi"}

staf = 10012673
print ("Staff ID %i is assigned to %s." % (staf, staffID[staf]))

# %% [markdown]
# Iterating over dictionaries

# %%
population = {"Denmark": 5760694, 
              "Austria": 8460390, 
              "Norway": 5342696}

for k, v in population.items():
    print (k, "has a population of", v)

# %% [markdown]
# Delete one of the key-values in a dictionary

# %%
del population["Austria"]

# %%
population

# %% [markdown]
# Add element to dictionary

# %%
population["Sweden"] = 9514406

#Element in dictionary
if ("Sweden" in population) == True:
    print ("Sweden is in the dictionary")

# %% [markdown]
# ### 📖Arrays
#
# Numpy is the mother library for dealing with arrays. Check [this](https://numpy.org) out!

# %%
from numpy import *
a = array ([1, 5, 10])
b = a * 2
print (b)

# %% [markdown]
# ### 📖File Handling

# %% [markdown]
# check your current working directory

# %%
import os
os.getcwd()

# %% [markdown]
# Siwtch to another directory – **choose one that actually exists on your computer!**
#
# Windows users, [take a look here](https://www.pitt.edu/~naraehan/python3/file_path_cwd.html).

# %% [markdown]
# let's create a text file and write a line into it

# %%
fh = open("hello.txt", "w") # W is for Writing a file and R for reading an existing file
lines_of_text = ["Hello"] # , "welcome to AAU", "we hope you enjoy the python course"
fh.writelines(lines_of_text)
fh.close()

# %% [markdown]
# let's write more lines

# %%
fh = open("hello.txt", "w")
lines_of_text = ["Hello!\n",  "welcome to NFDI4Earth!\n", "we hope you enjoy the python course\n"] 
fh.writelines(lines_of_text)
fh.close()

# %% [markdown]
# let's read the lines

# %%
fh = open("hello.txt","r")
print (fh.read())

# %%
fh = open("hello.txt","r")

for line in fh.readlines():
    print (line)
fh.close()

# %% [markdown]
# ### 📖Files and Directories

# %%
import os
# Get the current working directory
cwd = os.getcwd()
cwd

# %%
import os, sys

path = 'D:\\Other computers\\My PC\\B\\LMS\\Courses\\002_python_for_ spatial_data_analysis' # again, change this to a folder on your computer!

alldirs =[]
dirs = os.listdir(path)
# here we identify file extention
fileext = "txt" 

# This would print all the files and directories
for file in dirs:
    if file.endswith(fileext):
        alldirs.append(file)
        print (file)
        print (alldirs)
 
print ("%i files found." % (len(alldirs)))

# %% [markdown]
# ### 📖Error Handing

# %% [markdown]
# Exceptions allow you to prevent the program from crashing even when an error occurs:

# %%
# Try to convert the string "Test" to an integer (this will raise an error)
try:    
    int("Test")
# If an error occurs in the try block, catch the exception
except Exception as err:
    # Print out a custom error message along with the system-generated error
    print(("Error occured: ", err))
    # Terminate the script execution after encountering the error
    exit()

# %%
# Start an infinite loop
while True:  
    try:
        x = int(input("Please enter a number: "))
        break 
    # This block will be executed if the conversion above fails.
    except ValueError:  
        print("Oops!  That was no valid number.  Try again...")

# %%
try:
    outfile = open("x:/tmp/output.txt", "w")
    outfile.write("any output to file\n")
    outfile.close()
    print ("File successfully written.")

except Exception as err:
    print(("Could not write file: ", err))
    exit()

# %% [markdown]
# ### 📖Working with Time

# %%
import time
# Print the current time in seconds since the epoch (January 1, 1970, UTC)
print (time.time())

# %%
import time

# Record the current time before the loop starts
start = time.time()

# Run a loop from 1 to 999999 (it does nothing, but serves to consume time)
for i in range(1,1000000):
    pass

# Record the current time after the loop ends
end = time.time()

runtime = end - start
print ("Process took %.3f sec." % (runtime))

# %%
localtime = time.localtime(time.time())
print ("Year: ", localtime.tm_year)
print ("Month: ", localtime.tm_mon)
print ("Day: ", localtime.tm_mday)
